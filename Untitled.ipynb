# %%
import pandas as pd

# %%
county16 = pd.read_csv("county_2020.csv")
county20 = pd.read_csv("county_2016.csv")

# %%
state16 = pd.read_csv("state_2016.csv")
state20 = pd.read_csv("state_2020.csv")

# %%
state20.head()
# Out:
#   state  year  state_num   dem_num   rep_num     vap  state_electoral_votes
# 0    AK  2004     324078  115490.0  197521.0  747494                      3
# 1    AK  2008     331335  126068.0  196377.0  747494                      3
# 2    AK  2012     308459  125721.0  169220.0  761679                      3
# 3    AK  2016     325748  120605.0  165574.0  762934                      3
# 4    AK  2020     349411  150155.0  185807.0  528248                      3

# %%
dem.sort_values('year',ascending=False)
# Out:
#    demographic                          group  year  dem_frac  rep_frac  \
# 51   education  Some College to Post-Graduate  2016    0.5057    0.4225
# 38         age                        45 - 59  2016    0.4468    0.4800
# 15        race                          Other  2016    0.5732    0.3147
# 14        race                       Hispanic  2016    0.6863    0.2388
# 13        race             Non-Hispanic Black  2016    0.8999    0.0638
# 12        race             Non-Hispanic White  2016    0.3938    0.5380
# 22      gender                           male  2016    0.4548    0.4690
# 37         age                        30 - 44  2016    0.5552    0.3460
# 36         age                        17 - 29  2016    0.5483    0.3515
# 39         age                           60 +  2016    0.4753    0.4947
# 49   education          Less Than High School  2016    0.7223    0.2777
# 50   education               High School Grad  2016    0.4500    0.4870
# ...
